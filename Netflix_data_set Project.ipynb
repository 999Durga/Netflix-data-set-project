# %%
import numpy as np
import pandas as pd

# %%
netflix=pd.read_csv("netflix_titles.csv")
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix.isna()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
netflix.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
netflix.isna().any()
# Out:
# show_id         False
# type            False
# title           False
# director         True
# cast             True
# country          True
# date_added       True
# release_year    False
# rating           True
# duration         True
# listed_in       False
# description     False
# dtype: bool

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
netflix.shape
# Out:
# (8807, 12)

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix["director"].isnull().sum()
# Out:
# 2634

# %%
netflix["director"].fillna(netflix["director"].mode()[0],inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5896\1800498815.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   netflix["director"].fillna(netflix["director"].mode()[0],inplace=True)

# %%
netflix["director"].isnull().sum()
# Out:
# 0

# %%
netflix["cast"].isnull().sum()
# Out:
# 825

# %%
netflix["cast"].fillna(netflix["cast"].mode()[0],inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5896\650329287.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   netflix["cast"].fillna(netflix["cast"].mode()[0],inplace=True)

# %%
netflix["cast"].isnull().sum()
# Out:
# 0

# %%
netflix["country"].isnull().sum()
# Out:
# 831

# %%
netflix["country"].fillna(netflix["country"].mode()[0],inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5896\276118422.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   netflix["country"].fillna(netflix["country"].mode()[0],inplace=True)

# %%
netflix["country"].isnull().sum()
# Out:
# 0

# %%
netflix["date_added"].isnull().sum()
# Out:
# 10

# %%
netflix["date_added"].fillna(netflix["date_added"].mode()[0],inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5896\4118909084.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   netflix["date_added"].fillna(netflix["date_added"].mode()[0],inplace=True)

# %%
netflix["date_added"].isnull().sum()
# Out:
# 0

# %%
netflix["rating"].isnull().sum()
# Out:
# 4

# %%
netflix["rating"].fillna(netflix["rating"].mode()[0],inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5896\1075145192.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   netflix["rating"].fillna(netflix["rating"].mode()[0],inplace=True)

# %%
netflix["rating"].isnull().sum()
# Out:
# 0

# %%
netflix["duration"].isnull().sum()
# Out:
# 3

# %%
netflix["duration"].fillna(netflix["duration"].mode()[0],inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5896\4175395345.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   netflix["duration"].fillna(netflix["duration"].mode()[0],inplace=True)

# %%
netflix["duration"].isnull().sum()
# Out:
# 0

# %%
netflix["release_year"].describe()
# Out:
# count    8807.000000
# mean     2014.180198
# std         8.819312
# min      1925.000000
# 25%      2013.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
type_counts=netflix["type"].value_counts()

# %%
rating_counts=netflix["rating"].value_counts()

# %%
top_countries=netflix["country"].value_counts().head(10)

# %%
df=netflix.groupby(["country"]).groups
df
# Out:
# {', France, Algeria': [365], ', South Korea': [193], 'Argentina': [275, 303, 434, 673, 709, 769, 838, 1417, 1657, 1713, 1733, 1792, 1876, 1917, 2034, 2111, 2465, 2565, 2786, 2894, 3266, 3354, 3375, 3483, 3576, 3641, 3681, 3722, 3823, 4111, 4173, 4430, 4781, 4849, 4940, 4978, 5001, 5034, 5062, 5114, 5314, 5551, 6004, 6082, 6400, 6482, 6552, 6705, 6974, 7034, 7250, 7358, 7421, 7745, 7800, 8185], 'Argentina, Brazil, France, Poland, Germany, Denmark': [4947], 'Argentina, Chile': [1261, 8273], 'Argentina, Chile, Peru': [7362], 'Argentina, France': [4740], 'Argentina, France, United States, Germany, Qatar': [8163], 'Argentina, Italy': [4859], 'Argentina, Spain': [305, 2385, 3351, 4169, 4708, 4889, 5310, 6328], 'Argentina, United States': [3718], 'Argentina, United States, Mexico': [3287], 'Argentina, Uruguay, Serbia': [3091], 'Argentina, Uruguay, Spain, France': [5313], 'Argentina, Venezuela': [140], 'Australia': [25, 108, 120, 393, 506, 536, 682, 860, 1004, 1639, 1716, 1730, 1773, 1797, 1
# ...

# %%
netflix.head(50)
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                               Dick Johnson Is Dead
# 1       s2  TV Show                                      Blood & Water
# 2       s3  TV Show                                          Ganglands
# 3       s4  TV Show                              Jailbirds New Orleans
# 4       s5  TV Show                                       Kota Factory
# 5       s6  TV Show                                      Midnight Mass
# 6       s7    Movie                   My Little Pony: A New Generation
# 7       s8    Movie                                            Sankofa
# 8       s9  TV Show                      The Great British Baking Show
# 9      s10    Movie                                       The Starling
# 10     s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                                   Bangkok Breaking
# ...

# %%
df1=netflix.groupby(["director"]).groups
df1
# Out:
# {'A. L. Vijay': [3537, 6078], 'A. Raajdheep': [2389], 'A. Salaam': [5549], 'A.R. Murugadoss': [4049, 4681], 'Aadish Keluskar': [3602], 'Aamir Bashir': [5767], 'Aamir Khan': [1022], 'Aanand Rai': [2290], 'Aaron Burns': [7374], 'Aaron Hancox, Michael McNamara': [6434], 'Aaron Hann, Mario Miscione': [5892], 'Aaron Lieber': [2778], 'Aaron Nee, Adam Nee': [6226], 'Aaron Sorkin': [1842, 7479], 'Aaron Woodley': [2562], 'Aatmaram Dharne': [6439], 'Abba T. Makama': [2048, 6897], 'Abbas Alibhai Burmawalla, Mastan Alibhai Burmawalla': [2285, 4601, 6107, 7212], 'Abbas Mustan': [2074], 'Abbas Tyrewala': [1018], 'Abby Epstein': [3828], 'Abdellatif Kechiche': [6338], 'Abdul Aziz Hashad': [6531], 'Abdulaziz Alshlahei': [436], 'Abel Ferrara': [8715], 'Abhay Chopra': [4945], 'Abhijeet Deshpande': [2016], 'Abhijit Kokate, Srivinay Salian': [3729], 'Abhijit Panse': [2326, 2336], 'Abhinay Deo': [1016, 3136, 5587], 'Abhishek Chaubey': [1939, 1942, 5651], 'Abhishek Kapoor': [3145, 4445, 4722], 'Abhishek Sa
# ...

# %%
df1=netflix.groupby(["country"])
df1

# %%
df1.get_group("Turkey")
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5896\2866856975.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   df1.get_group("Turkey")
#      show_id     type                                         title  \
# 21       s22  TV Show                        Resurrection: Ertugrul
# 703     s704  TV Show                                      The Gift
# 906     s907    Movie  Have You Ever Seen Fireflies? - Theatre Play
# 972     s973  TV Show                                         Fatma
# 976     s977    Movie                                  Among Family
# ...      ...      ...                                           ...
# 7980   s7981    Movie                                   Sen Kimsin?
# 8682   s8683    Movie                               Vizontele Tuuba
# 8720   s8721  TV Show                     What Happens to My Family
# ...

# %%
netflix.loc[1:15,["title","director"]]
# Out:
#                                   title                       director
# 1                         Blood & Water                  Rajiv Chilaka
# 2                             Ganglands                Julien Leclercq
# 3                 Jailbirds New Orleans                  Rajiv Chilaka
# 4                          Kota Factory                  Rajiv Chilaka
# 5                         Midnight Mass                  Mike Flanagan
# 6      My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7                               Sankofa                   Haile Gerima
# 8         The Great British Baking Show                Andy Devonshire
# 9                          The Starling                 Theodore Melfi
# 10  Vendetta: Truth, Lies and The Mafia                  Rajiv Chilaka
# 11                     Bangkok Breaking              Kongkiat Komesiri
# 12                         Je Suis Karl            Christian Schwochow
# ...

# %%
netflix.iloc[1:10,1:5]
# Out:
#       type                             title                       director  \
# 1  TV Show                     Blood & Water                  Rajiv Chilaka
# 2  TV Show                         Ganglands                Julien Leclercq
# 3  TV Show             Jailbirds New Orleans                  Rajiv Chilaka
# 4  TV Show                      Kota Factory                  Rajiv Chilaka
# 5  TV Show                     Midnight Mass                  Mike Flanagan
# 6    Movie  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7    Movie                           Sankofa                   Haile Gerima
# 8  TV Show     The Great British Baking Show                Andy Devonshire
# 9    Movie                      The Starling                 Theodore Melfi
#
#                                                 cast
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...
